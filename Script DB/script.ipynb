-- %% [markdown]
-- # [tryDB]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [tryDB]    Script Date: 04/12/2024 4:02:10 PM ******/
CREATE DATABASE [tryDB]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'tryDB', FILENAME = N'C:\Users\USER\tryDB.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'tryDB_log', FILENAME = N'C:\Users\USER\tryDB_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [tryDB] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [tryDB].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [tryDB] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [tryDB] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [tryDB] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [tryDB] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [tryDB] SET ARITHABORT OFF 
GO
ALTER DATABASE [tryDB] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [tryDB] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [tryDB] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [tryDB] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [tryDB] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [tryDB] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [tryDB] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [tryDB] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [tryDB] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [tryDB] SET  DISABLE_BROKER 
GO
ALTER DATABASE [tryDB] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [tryDB] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [tryDB] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [tryDB] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [tryDB] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [tryDB] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [tryDB] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [tryDB] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [tryDB] SET  MULTI_USER 
GO
ALTER DATABASE [tryDB] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [tryDB] SET DB_CHAINING OFF 
GO
ALTER DATABASE [tryDB] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [tryDB] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [tryDB] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [tryDB] SET QUERY_STORE = OFF
GO
USE [tryDB]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [dbo].[tbl_deployDetails]

-- %%
USE [tryDB]
GO

-- %%
/****** Object:  Table [dbo].[tbl_deployDetails]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_deployDetails](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[dateDeploy] [datetime] NULL,
	[oldUser] [varchar](50) NULL,
	[setID] [int] NOT NULL,
	[oldID] [int] NULL,
 CONSTRAINT [PK_tbl_deployDetails] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_status]

-- %%
/****** Object:  Table [dbo].[tbl_status]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_status](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[status] [varchar](50) NOT NULL,
	[statusName] [varchar](50) NOT NULL,
 CONSTRAINT [PK_tbl_status] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_assets]

-- %%
/****** Object:  Table [dbo].[tbl_assets]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_assets](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[category] [varchar](50) NOT NULL,
	[brand] [varchar](50) NULL,
	[specs] [varchar](250) NULL,
	[serial] [varchar](250) NULL,
	[status] [varchar](50) NOT NULL,
	[remarks] [varchar](250) NULL,
	[date] [datetime] NOT NULL,
	[action] [int] NULL,
	[deployID] [int] NULL,
	[userID] [int] NULL,
	[pullOutID] [int] NULL,
	[oldUser] [varchar](50) NULL,
	[statusID] [int] NULL,
 CONSTRAINT [PK_tbl_assets] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vGrid_deployDetails]

-- %%
/****** Object:  View [dbo].[vGrid_deployDetails]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[vGrid_deployDetails]
AS
SELECT        dbo.tbl_assets.id, dbo.tbl_assets.category, dbo.tbl_assets.brand, dbo.tbl_assets.specs, dbo.tbl_assets.serial, dbo.tbl_assets.remarks, dbo.tbl_deployDetails.dateDeploy, dbo.tbl_assets.oldUser, dbo.tbl_assets.action, 
                         dbo.tbl_assets.status, dbo.tbl_status.statusName
FROM            dbo.tbl_assets INNER JOIN
                         dbo.tbl_status ON dbo.tbl_assets.statusID = dbo.tbl_status.id LEFT OUTER JOIN
                         dbo.tbl_deployDetails ON dbo.tbl_assets.deployID = dbo.tbl_deployDetails.id
GO

-- %% [markdown]
-- # [dbo].[tbl_DeploymentUser]

-- %%
/****** Object:  Table [dbo].[tbl_DeploymentUser]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_DeploymentUser](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[userID] [int] NOT NULL,
 CONSTRAINT [PK_tbl_DeploymentUser] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_users]

-- %%
/****** Object:  Table [dbo].[tbl_users]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_users](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[fullName] [varchar](50) NOT NULL,
	[isResign] [int] NULL,
 CONSTRAINT [PK_tbl_users] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vGrid_deployUser]

-- %%
/****** Object:  View [dbo].[vGrid_deployUser]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[vGrid_deployUser]
AS
SELECT        dbo.tbl_users.id, dbo.tbl_users.fullName
FROM            dbo.tbl_DeploymentUser INNER JOIN
                         dbo.tbl_users ON dbo.tbl_DeploymentUser.userID = dbo.tbl_users.id
GO

-- %% [markdown]
-- # [dbo].[vGrid_finalDeployViewDetails]

-- %%
/****** Object:  View [dbo].[vGrid_finalDeployViewDetails]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[vGrid_finalDeployViewDetails]
AS
SELECT        TOP (100) PERCENT dbo.tbl_users.fullName, dbo.tbl_assets.id, dbo.tbl_assets.category, dbo.tbl_assets.brand, dbo.tbl_assets.specs, dbo.tbl_assets.serial, dbo.tbl_assets.remarks, dbo.tbl_assets.action, 
                         dbo.tbl_deployDetails.dateDeploy, dbo.tbl_assets.oldUser, dbo.tbl_assets.userID
FROM            dbo.tbl_users INNER JOIN
                         dbo.tbl_deployDetails ON dbo.tbl_users.id = dbo.tbl_deployDetails.setID INNER JOIN
                         dbo.tbl_assets ON dbo.tbl_deployDetails.id = dbo.tbl_assets.deployID
GO

-- %% [markdown]
-- # [dbo].[tbl_pulloutDetails]

-- %%
/****** Object:  Table [dbo].[tbl_pulloutDetails]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_pulloutDetails](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[datePullout] [datetime] NULL,
	[userID] [int] NULL,
 CONSTRAINT [PK_tbl_pulloutDetails] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vGrid_finalPullOut]

-- %%
/****** Object:  View [dbo].[vGrid_finalPullOut]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[vGrid_finalPullOut]
AS
SELECT        dbo.tbl_users.fullName, dbo.tbl_assets.id, dbo.tbl_assets.category, dbo.tbl_assets.brand, dbo.tbl_assets.specs, dbo.tbl_assets.serial, dbo.tbl_assets.remarks, dbo.tbl_pulloutDetails.datePullout, dbo.tbl_assets.action, 
                         dbo.tbl_assets.oldUser
FROM            dbo.tbl_assets INNER JOIN
                         dbo.tbl_pulloutDetails ON dbo.tbl_assets.pullOutID = dbo.tbl_pulloutDetails.id INNER JOIN
                         dbo.tbl_users ON dbo.tbl_assets.userID = dbo.tbl_users.id INNER JOIN
                         dbo.tbl_deployDetails ON dbo.tbl_assets.deployID = dbo.tbl_deployDetails.id AND dbo.tbl_users.id = dbo.tbl_deployDetails.setID
GO

-- %% [markdown]
-- # [dbo].[vGrid_pulloutDetails]

-- %%
/****** Object:  View [dbo].[vGrid_pulloutDetails]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE VIEW [dbo].[vGrid_pulloutDetails]
AS
SELECT        dbo.tbl_assets.id, dbo.tbl_users.fullName, dbo.tbl_assets.category, dbo.tbl_assets.brand, dbo.tbl_assets.specs, dbo.tbl_assets.serial, dbo.tbl_assets.remarks, dbo.tbl_pulloutDetails.datePullout, dbo.tbl_assets.action
FROM            dbo.tbl_assets INNER JOIN
                         dbo.tbl_pulloutDetails ON dbo.tbl_assets.id = dbo.tbl_pulloutDetails.id INNER JOIN
                         dbo.tbl_users ON dbo.tbl_assets.id = dbo.tbl_users.id
GO

-- %% [markdown]
-- # [dbo].[vGrid_ViewDetails]

-- %%
/****** Object:  View [dbo].[vGrid_ViewDetails]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE VIEW [dbo].[vGrid_ViewDetails]
AS
SELECT        dbo.tbl_users.fullName, dbo.tbl_assets.id, dbo.tbl_assets.category, dbo.tbl_assets.brand, dbo.tbl_assets.specs, dbo.tbl_assets.serial, dbo.tbl_assets.remarks, dbo.tbl_deployDetails.dateDeploy, dbo.tbl_deployDetails.oldUser, 
                         dbo.tbl_deployDetails.setID, dbo.tbl_assets.action
FROM            dbo.tbl_assets INNER JOIN
                         dbo.tbl_deployDetails ON dbo.tbl_assets.deployID = dbo.tbl_deployDetails.id INNER JOIN
                         dbo.tbl_users ON dbo.tbl_deployDetails.setID = dbo.tbl_users.id
GO

-- %% [markdown]
-- # [dbo].[vGrid_assets]

-- %%
/****** Object:  View [dbo].[vGrid_assets]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[vGrid_assets]
AS
SELECT        dbo.tbl_assets.id, dbo.tbl_assets.category, dbo.tbl_assets.brand, dbo.tbl_assets.specs, dbo.tbl_assets.serial, dbo.tbl_assets.remarks, dbo.tbl_assets.date, dbo.tbl_assets.status, dbo.tbl_status.statusName, 
                         dbo.tbl_assets.action, dbo.tbl_assets.oldUser
FROM            dbo.tbl_assets INNER JOIN
                         dbo.tbl_status ON dbo.tbl_assets.statusID = dbo.tbl_status.id
GO

-- %% [markdown]
-- # [dbo].[tbl_archive]

-- %%
/****** Object:  Table [dbo].[tbl_archive]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_archive](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[setID] [int] NOT NULL,
	[dateDelete] [date] NOT NULL,
	[category] [varchar](50) NOT NULL,
	[brand] [varchar](50) NOT NULL,
	[specs] [varchar](50) NOT NULL,
	[serial] [varchar](50) NOT NULL,
	[status] [varchar](50) NOT NULL,
	[remarks] [varchar](50) NOT NULL,
	[statusID] [int] NULL,
 CONSTRAINT [PK_tbl_archive] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[vGrid_archive]

-- %%
/****** Object:  View [dbo].[vGrid_archive]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[vGrid_archive]
AS
SELECT        dbo.tbl_archive.id, dbo.tbl_archive.setID, dbo.tbl_archive.dateDelete, dbo.tbl_archive.category, dbo.tbl_archive.brand, dbo.tbl_archive.specs, dbo.tbl_archive.serial, dbo.tbl_status.status, dbo.tbl_status.statusName, 
                         dbo.tbl_archive.remarks
FROM            dbo.tbl_archive INNER JOIN
                         dbo.tbl_status ON dbo.tbl_archive.statusID = dbo.tbl_status.id
GO

-- %% [markdown]
-- # [dbo].[vGrid_pulloutUsers]

-- %%
/****** Object:  View [dbo].[vGrid_pulloutUsers]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[vGrid_pulloutUsers]
AS
SELECT        dbo.tbl_users.id, dbo.tbl_users.fullName, dbo.tbl_assets.action
FROM            dbo.tbl_users INNER JOIN
                         dbo.tbl_assets ON dbo.tbl_users.id = dbo.tbl_assets.id
GO

-- %% [markdown]
-- # [dbo].[tbl_accounts]

-- %%
/****** Object:  Table [dbo].[tbl_accounts]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_accounts](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[username] [varchar](50) NOT NULL,
	[password] [varchar](50) NOT NULL,
 CONSTRAINT [PK_tbl_accounts] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_category]

-- %%
/****** Object:  Table [dbo].[tbl_category]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_category](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[category] [varchar](50) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_pulloutUser]

-- %%
/****** Object:  Table [dbo].[tbl_pulloutUser]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_pulloutUser](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[userID] [int] NOT NULL,
 CONSTRAINT [PK_tbl_pulloutUser] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_tryAssets]

-- %%
/****** Object:  Table [dbo].[tbl_tryAssets]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_tryAssets](
	[id] [int] NOT NULL,
	[category] [varchar](50) NULL,
	[brand] [varchar](50) NULL,
	[specs] [varchar](50) NULL,
	[serial] [varchar](50) NULL,
	[status] [varchar](50) NULL,
	[quantity] [int] NOT NULL,
	[remarks] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tbl_tryUsers]

-- %%
/****** Object:  Table [dbo].[tbl_tryUsers]    Script Date: 04/12/2024 4:02:10 PM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tbl_tryUsers](
	[id] [int] NOT NULL,
	[name] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_tbl_archive_tbl_status]

-- %%
ALTER TABLE [dbo].[tbl_archive]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_archive_tbl_status] FOREIGN KEY([statusID])
REFERENCES [dbo].[tbl_status] ([id])
GO
ALTER TABLE [dbo].[tbl_archive] NOCHECK CONSTRAINT [FK_tbl_archive_tbl_status]
GO

-- %% [markdown]
-- # [FK_tbl_assets_tbl_deployDetails]

-- %%
ALTER TABLE [dbo].[tbl_assets]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_assets_tbl_deployDetails] FOREIGN KEY([deployID])
REFERENCES [dbo].[tbl_deployDetails] ([id])
GO
ALTER TABLE [dbo].[tbl_assets] NOCHECK CONSTRAINT [FK_tbl_assets_tbl_deployDetails]
GO

-- %% [markdown]
-- # [FK_tbl_assets_tbl_pulloutDetails]

-- %%
ALTER TABLE [dbo].[tbl_assets]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_assets_tbl_pulloutDetails] FOREIGN KEY([pullOutID])
REFERENCES [dbo].[tbl_pulloutDetails] ([id])
GO
ALTER TABLE [dbo].[tbl_assets] NOCHECK CONSTRAINT [FK_tbl_assets_tbl_pulloutDetails]
GO

-- %% [markdown]
-- # [FK_tbl_assets_tbl_status]

-- %%
ALTER TABLE [dbo].[tbl_assets]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_assets_tbl_status] FOREIGN KEY([statusID])
REFERENCES [dbo].[tbl_status] ([id])
GO
ALTER TABLE [dbo].[tbl_assets] NOCHECK CONSTRAINT [FK_tbl_assets_tbl_status]
GO

-- %% [markdown]
-- # [FK_tbl_assets_tbl_users]

-- %%
ALTER TABLE [dbo].[tbl_assets]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_assets_tbl_users] FOREIGN KEY([userID])
REFERENCES [dbo].[tbl_users] ([id])
GO
ALTER TABLE [dbo].[tbl_assets] NOCHECK CONSTRAINT [FK_tbl_assets_tbl_users]
GO

-- %% [markdown]
-- # [FK_tbl_deployDetails_tbl_users]

-- %%
ALTER TABLE [dbo].[tbl_deployDetails]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_deployDetails_tbl_users] FOREIGN KEY([setID])
REFERENCES [dbo].[tbl_users] ([id])
GO
ALTER TABLE [dbo].[tbl_deployDetails] NOCHECK CONSTRAINT [FK_tbl_deployDetails_tbl_users]
GO

-- %% [markdown]
-- # [FK_tbl_pulloutDetails_tbl_users]

-- %%
ALTER TABLE [dbo].[tbl_pulloutDetails]  WITH NOCHECK ADD  CONSTRAINT [FK_tbl_pulloutDetails_tbl_users] FOREIGN KEY([userID])
REFERENCES [dbo].[tbl_users] ([id])
GO
ALTER TABLE [dbo].[tbl_pulloutDetails] NOCHECK CONSTRAINT [FK_tbl_pulloutDetails_tbl_users]
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[40] 4[20] 2[20] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_archive"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 249
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_status"
            Begin Extent = 
               Top = 6
               Left = 246
               Bottom = 119
               Right = 416
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 11
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1710
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_archive'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_archive'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[55] 4[6] 2[21] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 284
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 2
         End
         Begin Table = "tbl_status"
            Begin Extent = 
               Top = 8
               Left = 298
               Bottom = 121
               Right = 468
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 9
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_assets'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_assets'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[57] 4[6] 2[14] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 290
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 2
         End
         Begin Table = "tbl_deployDetails"
            Begin Extent = 
               Top = 6
               Left = 292
               Bottom = 136
               Right = 462
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_status"
            Begin Extent = 
               Top = 169
               Left = 292
               Bottom = 282
               Right = 462
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 12
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_deployDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_deployDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[40] 4[20] 2[20] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_DeploymentUser"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 130
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_users"
            Begin Extent = 
               Top = 5
               Left = 359
               Bottom = 150
               Right = 529
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 9
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_deployUser'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_deployUser'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[47] 4[5] 2[20] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_users"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 103
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_deployDetails"
            Begin Extent = 
               Top = 143
               Left = 49
               Bottom = 284
               Right = 219
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 2
               Left = 536
               Bottom = 290
               Right = 706
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 12
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_finalDeployViewDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_finalDeployViewDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[47] 4[22] 2[1] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 226
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 4
         End
         Begin Table = "tbl_pulloutDetails"
            Begin Extent = 
               Top = 12
               Left = 354
               Bottom = 128
               Right = 524
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_users"
            Begin Extent = 
               Top = 134
               Left = 354
               Bottom = 230
               Right = 524
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_deployDetails"
            Begin Extent = 
               Top = 13
               Left = 641
               Bottom = 143
               Right = 811
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 13
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1980
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
   ' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_finalPullOut'
GO

-- %% [markdown]
-- # [MS_DiagramPane2]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane2', @value=N'      GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_finalPullOut'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=2 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_finalPullOut'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[57] 4[6] 2[21] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 280
               Right = 206
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_pulloutDetails"
            Begin Extent = 
               Top = 108
               Left = 256
               Bottom = 211
               Right = 426
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_users"
            Begin Extent = 
               Top = 6
               Left = 454
               Bottom = 114
               Right = 624
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 10
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_pulloutDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_pulloutDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[54] 4[8] 2[21] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_users"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 135
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 6
               Left = 246
               Bottom = 275
               Right = 416
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 9
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_pulloutUsers'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_pulloutUsers'
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[50] 4[12] 2[21] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = 0
         Left = 0
      End
      Begin Tables = 
         Begin Table = "tbl_assets"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 255
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_deployDetails"
            Begin Extent = 
               Top = 6
               Left = 246
               Bottom = 145
               Right = 416
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "tbl_users"
            Begin Extent = 
               Top = 13
               Left = 540
               Bottom = 109
               Right = 710
            End
            DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
      Begin ColumnWidths = 11
         Width = 284
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
         Width = 1500
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 1440
         Alias = 900
         Table = 1170
         Output = 720
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_ViewDetails'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=1 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'vGrid_ViewDetails'
GO

-- %% [markdown]
-- # [tryDB]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [tryDB] SET  READ_WRITE 
GO
